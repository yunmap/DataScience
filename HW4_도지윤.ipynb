# %%
import pandas as pd
import numpy as np

# %%
tip = pd.read_csv('tip.csv')

# %%
business = pd.read_csv('business.csv')

# %%
user = pd.read_csv('user.csv')

# %%
review = pd.read_csv('review.csv')

# %%
tip.head()
# Out:
#    user_id  business_id  likes        date type
# 0  5156914        49959      0  2012-07-15  tip
# 1  2972349       120102      0  2015-08-12  tip
# 2  4841143        98242      0  2014-06-20  tip
# 3  2120780        98242      0  2016-10-12  tip
# 4  2120780        63215      0  2016-07-03  tip

# %%
business.head()
# Out:
#   neighborhood  business_id  \
# 0   Unionville            0
# 1          NaN            1
# 2          NaN            2
# 3   South Park            3
# 4     Downtown            4
#
#                                                hours  is_open  \
# 0  ['Monday 7:0-18:0', 'Tuesday 7:0-18:0', 'Wedne...        0
# 1                                                NaN        1
# 2  ['Monday 7:0-14:0', 'Tuesday 7:0-14:0', 'Wedne...        1
# 3  ['Monday 11:0-2:0', 'Tuesday 11:0-2:0', 'Wedne...        1
# 4                                                NaN        1
#
#                                  address  \
# 0  139 Main Street Unionville, Suite 105
# 1                     12665 Corporate Dr
# 2                   6219 E Cave Creek Rd
# 3                       1518 Montford Dr
# 4                   333 Las Vegas Blvd S
#
#                                           attributes  \
# 0  ['Alcohol: none', "Ambience: {'romantic': Fals...
# ...

# %%
user.head()
# Out:
#   yelping_since  useful  compliment_photos  compliment_list  compliment_funny  \
# 0    2008-10-30      -1                  0                0                 0
# 1    2015-05-31       0                  0                0                 0
# 2    2010-07-07      88                  2                0                16
# 3    2014-09-02       0                  0                0                 0
# 4    2014-11-12       1                  0                0                 0
#
#    compliment_plain  review_count     elite  fans  type       ...         \
# 0                 0            53  ['None']     0  user       ...
# 1                 0             2  ['None']     0  user       ...
# 2                25           159  ['None']    11  user       ...
# 3                 0             5  ['None']     1  user       ...
# 4                 0            28  ['None']     1  user       ...
#
#    compliment_cute  average_stars  user_id  compliment_more  \
# ...

# %%
review.head()
# Out:
#    funny  user_id  review_id  business_id  stars        date  useful    type  \
# 0      0  4459923          0         8835      5  2015-08-17       0  review
# 1      1  1794716          1        22335      1  2010-01-20       0  review
# 2      0  4226778          2        87180      1  2016-11-03       0  review
# 3      2   833221          3       122055      2  2015-07-17       0  review
# 4      0  1731577          4        75820      2  2015-11-19       0  review
#
#    cool
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144072 entries, 0 to 144071
# Data columns (total 16 columns):
# neighborhood    57909 non-null object
# business_id     144072 non-null int64
# hours           102464 non-null object
# is_open         144072 non-null int64
# address         139838 non-null object
# attributes      127162 non-null object
# categories      143747 non-null object
# city            144071 non-null object
# review_count    144072 non-null int64
# name            144072 non-null object
# longitude       144072 non-null float64
# state           144072 non-null object
# stars           144072 non-null float64
# latitude        144072 non-null float64
# postal_code     143336 non-null object
# type            144072 non-null object
# dtypes: float64(3), int64(3), object(10)
# memory usage: 17.6+ MB

# %%
business_ori=business

# %%
business = business.drop('neighborhood', axis=1)
business = business.drop('hours', axis=1)
business = business.drop('is_open', axis=1)
business = business.drop('address',axis=1)
business = business.drop('attributes', axis=1)
business = business.drop('city',axis=1)
business = business.drop('name', axis=1)
business = business.drop('longitude',axis=1)
business = business.drop('state', axis=1)
business = business.drop('latitude',axis=1)
business = business.drop('postal_code', axis=1)

# %%
business
# Out:
#         business_id                                         categories  \
# 0                 0  ['Coffee & Tea', 'Desserts', 'Restaurants', 'I...
# 1                 1   ['Gyms', 'Active Life', 'Fitness & Instruction']
# 2                 2    ['Diners', 'Breakfast & Brunch', 'Restaurants']
# 3                 3  ['Pubs', 'Restaurants', 'Bars', 'Pool Halls', ...
# 4                 4                           ['Food', 'Coffee & Tea']
# 5                 5              ['Mexican', 'Tex-Mex', 'Restaurants']
# 6                 6  ['Fitness & Instruction', 'Yoga', 'Sporting Go...
# 7                 7  ['Restaurants', 'American (New)', 'Nightlife',...
# 8                 8  ['Education', 'Middle Schools & High Schools',...
# 9                 9  ['Real Estate Law', 'Real Estate', 'Profession...
# 10               10       ['Shopping', 'Department Stores', 'Fashion']
# 11               11                     ['Restaurants', 'Steakhouses']
# ...

# %%
business = business.drop('type',axis=1)
business = business.drop('categories',axis=1)

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029432 entries, 0 to 1029431
# Data columns (total 23 columns):
# yelping_since         1029432 non-null object
# useful                1029432 non-null int64
# compliment_photos     1029432 non-null int64
# compliment_list       1029432 non-null int64
# compliment_funny      1029432 non-null int64
# compliment_plain      1029432 non-null int64
# review_count          1029432 non-null int64
# elite                 1029432 non-null object
# fans                  1029432 non-null int64
# type                  1029432 non-null object
# compliment_note       1029432 non-null int64
# funny                 1029432 non-null int64
# compliment_writer     1029432 non-null int64
# compliment_cute       1029432 non-null int64
# average_stars         1029432 non-null float64
# user_id               1029432 non-null int64
# compliment_more       1029432 non-null int64
# friends               1029432 non-null object
# ...

# %%
user_ori = user

# %%
user = user.drop('type',axis=1)
user = user.drop('name',axis=1)

# %%
user
# Out:
#         yelping_since  useful  compliment_photos  compliment_list  \
# 0          2008-10-30      -1                  0                0
# 1          2015-05-31       0                  0                0
# 2          2010-07-07      88                  2                0
# 3          2014-09-02       0                  0                0
# 4          2014-11-12       1                  0                0
# 5          2014-07-27       0                  0                0
# 6          2013-03-02       0                  0                0
# 7          2012-05-27       0                  0                0
# 8          2013-07-04       0                  0                0
# 9          2008-01-30       3                  0                0
# 10         2008-10-27       2                  0                1
# 11         2014-07-16       0                  0                0
# 12         2014-05-02       2                  0                0
# ...

# %%
user = user.drop('yelping_since',axis=1)

# %%
user
# Out:
#          useful  compliment_photos  compliment_list  compliment_funny  \
# 0            -1                  0                0                 0
# 1             0                  0                0                 0
# 2            88                  2                0                16
# 3             0                  0                0                 0
# 4             1                  0                0                 0
# 5             0                  0                0                 0
# 6             0                  0                0                 0
# 7             0                  0                0                 0
# 8             0                  0                0                 0
# 9             3                  0                0                 0
# 10            2                  0                1                 0
# 11            0                  0                0                 0
# ...

# %%
user = user.drop('compliment_photos',axis=1)
user = user.drop('compliment_list',axis=1)
user = user.drop('compliment_funny',axis=1)
user = user.drop('compliment_plain', axis=1)
user = user.drop('fans',axis=1)
user = user.drop('compliment_note',axis=1)
user = user.drop('compliment_writer',axis=1)
user = user.drop('compliment_cute',axis=1)
user = user.drop('funny',axis=1)
user = user.drop('compliment_more',axis=1)
user = user.drop('compliment_hot',axis=1)
user = user.drop('compliment_profile',axis=1)
user = user.drop('compliment_cool',axis=1)
user = user.drop('cool',axis=1)

# %%
user
# Out:
#          useful  review_count             elite  average_stars  user_id  \
# 0            -1            53          ['None']           4.82  4194305
# 1             0             2          ['None']           5.00        5
# 2            88           159          ['None']           3.58        6
# 3             0             5          ['None']           1.13  6291463
# 4             1            28          ['None']           4.03  6291465
# 5             0             7          ['None']           3.29  4194314
# 6             0            10          ['None']           3.83       11
# 7             0             3          ['None']           5.00  4194316
# 8             0             4          ['None']           3.00       15
# 9             3             7          ['None']           2.20  2097168
# 10            2            24          ['None']           3.42       18
# 11            0             6          ['None']           3.83       22
# ...

# %%
user = user.drop('elite',axis=1)
user = user.drop('friends',axis=1)

# %%
user
# Out:
#          useful  review_count  average_stars  user_id
# 0            -1            53           4.82  4194305
# 1             0             2           5.00        5
# 2            88           159           3.58        6
# 3             0             5           1.13  6291463
# 4             1            28           4.03  6291465
# 5             0             7           3.29  4194314
# 6             0            10           3.83       11
# 7             0             3           5.00  4194316
# 8             0             4           3.00       15
# 9             3             7           2.20  2097168
# 10            2            24           3.42       18
# 11            0             6           3.83       22
# 12            2            23           3.96  6291479
# 13            0             5           3.00  2097177
# 14            1             1           1.00  2930145
# 15            0             2           2.50       28
# ...

# %%
review
# Out:
#          funny  user_id  review_id  business_id  stars        date  useful  \
# 0            0  4459923          0         8835      5  2015-08-17       0
# 1            1  1794716          1        22335      1  2010-01-20       0
# 2            0  4226778          2        87180      1  2016-11-03       0
# 3            2   833221          3       122055      2  2015-07-17       0
# 4            0  1731577          4        75820      2  2015-11-19       0
# 5            1  2628880          5       118849      5  2015-07-19       2
# 6            0  1724127          6        40580      5  2015-09-17       0
# 7            0  4832757          7        82830      4  2013-02-09       2
# 8            0  6967162          8        45874      5  2012-05-18       0
# 9            0  5276758          9        64424      5  2012-10-14       0
# 10           0  3761196         10        86609      1  2015-04-09       1
# ...

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3753149 entries, 0 to 3753148
# Data columns (total 9 columns):
# funny          int64
# user_id        int64
# review_id      int64
# business_id    int64
# stars          int64
# date           object
# useful         int64
# type           object
# cool           int64
# dtypes: int64(7), object(2)
# memory usage: 257.7+ MB

# %%
review_ori=review

# %%
review = review.drop('funny', axis=1)
review = review.drop('date', axis=1)
review = review.drop('type', axis=1)
review = review.drop('cool', axis=1)
review = review.drop('useful', axis=1)

# %%
review
# Out:
#          user_id  review_id  business_id  stars
# 0        4459923          0         8835      5
# 1        1794716          1        22335      1
# 2        4226778          2        87180      1
# 3         833221          3       122055      2
# 4        1731577          4        75820      2
# 5        2628880          5       118849      5
# 6        1724127          6        40580      5
# 7        4832757          7        82830      4
# 8        6967162          8        45874      5
# 9        5276758          9        64424      5
# 10       3761196         10        86609      1
# 11       5359766         12        19799      4
# 12       1863465         13        41529      3
# 13       7191163         15        48929      5
# 14       1736428         16        18527      1
# 15       3759620         17       107274      4
# 16       2306895         18       132897      2
# 17       6458032         19        64031      4
# 18       1124932         20        83035      4
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import train_test_split
# Out:
# C:\Users\lgpc\Anaconda\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
business.head()
# Out:
#    business_id  review_count  stars
# 0            0            12    4.0
# 1            1             4    3.0
# 2            2            79    3.5
# 3            3           105    3.0
# 4            4             4    3.0

# %%
user.head()
# Out:
#    useful  review_count  average_stars  user_id
# 0      -1            53           4.82  4194305
# 1       0             2           5.00        5
# 2      88           159           3.58        6
# 3       0             5           1.13  6291463
# 4       1            28           4.03  6291465

# %%
review.head()
# Out:
#    user_id  review_id  business_id  stars
# 0  4459923          0         8835      5
# 1  1794716          1        22335      1
# 2  4226778          2        87180      1
# 3   833221          3       122055      2
# 4  1731577          4        75820      2

# %%
total = pd.merge(user,review,how='right',on=['user_id'])

# %%
total1 = pd.merge(total, business, how='left', on=['business_id'])

# %%
total.head()
# Out:
#    useful  review_count  average_stars  user_id  review_id  business_id  stars
# 0      -1            53           4.82  4194305     162222         4899      5
# 1      -1            53           4.82  4194305     174594        49445      5
# 2      -1            53           4.82  4194305     270709       134952      5
# 3      -1            53           4.82  4194305     385483        73253      5
# 4      -1            53           4.82  4194305     420963       117252      5

# %%
total1.head()
# Out:
#    useful  review_count_x  average_stars  user_id  review_id  business_id  \
# 0      -1              53           4.82  4194305     162222         4899
# 1      -1              53           4.82  4194305     174594        49445
# 2      -1              53           4.82  4194305     270709       134952
# 3      -1              53           4.82  4194305     385483        73253
# 4      -1              53           4.82  4194305     420963       117252
#
#    stars_x  review_count_y  stars_y
# 0        5              10      3.0
# 1        5               3      4.0
# 2        5               5      4.0
# 3        5              16      4.0
# 4        5              55      4.5

# %%
total1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3753149 entries, 0 to 3753148
# Data columns (total 9 columns):
# useful            int64
# review_count_x    int64
# average_stars     float64
# user_id           int64
# review_id         int64
# business_id       int64
# stars_x           int64
# review_count_y    int64
# stars_y           float64
# dtypes: float64(2), int64(7)
# memory usage: 286.3 MB

# %%
total1.dropna()
# Out:
#          useful  review_count_x  average_stars  user_id  review_id  \
# 0            -1              53           4.82  4194305     162222
# 1            -1              53           4.82  4194305     174594
# 2            -1              53           4.82  4194305     270709
# 3            -1              53           4.82  4194305     385483
# 4            -1              53           4.82  4194305     420963
# 5            -1              53           4.82  4194305     579746
# 6            -1              53           4.82  4194305     585788
# 7            -1              53           4.82  4194305     875627
# 8            -1              53           4.82  4194305     908766
# 9            -1              53           4.82  4194305    1091222
# 10           -1              53           4.82  4194305    1166696
# 11           -1              53           4.82  4194305    1228589
# 12           -1              53           4.82  4194305    1336907
# ...

# %%
total1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3753149 entries, 0 to 3753148
# Data columns (total 9 columns):
# useful            int64
# review_count_x    int64
# average_stars     float64
# user_id           int64
# review_id         int64
# business_id       int64
# stars_x           int64
# review_count_y    int64
# stars_y           float64
# dtypes: float64(2), int64(7)
# memory usage: 286.3 MB

# %%
total1.drop('review_id',axis=1)
# Out:
#          useful  review_count_x  average_stars  user_id  business_id  stars_x  \
# 0            -1              53           4.82  4194305         4899        5
# 1            -1              53           4.82  4194305        49445        5
# 2            -1              53           4.82  4194305       134952        5
# 3            -1              53           4.82  4194305        73253        5
# 4            -1              53           4.82  4194305       117252        5
# 5            -1              53           4.82  4194305        98037        5
# 6            -1              53           4.82  4194305        27721        5
# 7            -1              53           4.82  4194305         4495        5
# 8            -1              53           4.82  4194305        34629        4
# 9            -1              53           4.82  4194305        16658        5
# 10           -1              53           4.82  4194305        57923        5
# ...

# %%
total.sort_values(by='review_id')
# Out:
#          useful  review_count  average_stars  user_id  review_id  business_id  \
# 540370        1             2           5.00  4459923          0         8835
# 3264976       3            74           3.89  1794716          1        22335
# 67076         2             9           3.00  4226778          2        87180
# 1658471       6            13           3.71   833221          3       122055
# 3161585      11            37           4.18  1731577          4        75820
# 2106806       0             7           3.29  2628880          5       118849
# 3149026       0             4           4.50  1724127          6        40580
# 1277106      19           250           3.92  4832757          7        82830
# 3529555     -14           154           3.71  6967162          8        45874
# 2088411       0             8           4.50  5276758          9        64424
# 3049099       0             3           3.67  3761196         10        86609
# ...

# %%
total = total.dropna(axis=0)

# %%
total = total.drop('review_id',axis=1)

# %%
total
# Out:
#          useful  review_count  average_stars  user_id  business_id  stars
# 0            -1            53           4.82  4194305         4899      5
# 1            -1            53           4.82  4194305        49445      5
# 2            -1            53           4.82  4194305       134952      5
# 3            -1            53           4.82  4194305        73253      5
# 4            -1            53           4.82  4194305       117252      5
# 5            -1            53           4.82  4194305        98037      5
# 6            -1            53           4.82  4194305        27721      5
# 7            -1            53           4.82  4194305         4495      5
# 8            -1            53           4.82  4194305        34629      4
# 9            -1            53           4.82  4194305        16658      5
# 10           -1            53           4.82  4194305        57923      5
# 11           -1            53           4.82  4194305       121436      5
# ...

# %%
X = total.drop('stars',axis=1)
y = total['stars']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.70, random_state=50)
clf = KNeighborsClassifier(n_neighbors=4)
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#            weights='uniform')

# %%
X1 = total1.drop('stars_x',axis=1)
X1 = X1.drop('review_id',axis=1)
y1 = total1['stars_x']

# %%
X1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3753149 entries, 0 to 3753148
# Data columns (total 8 columns):
# useful            int64
# review_count_x    int64
# average_stars     float64
# user_id           int64
# review_id         int64
# business_id       int64
# review_count_y    int64
# stars_y           float64
# dtypes: float64(2), int64(6)
# memory usage: 257.7 MB

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, train_size=0.70, random_state=10000)
clf1 = KNeighborsClassifier(n_neighbors=5)
clf1.fit(X_train1, y_train1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-71d9500f7a8f> in <module>()
#       1 X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, train_size=0.70, random_state=10000)
#       2 clf1 = KNeighborsClassifier(n_neighbors=5)
# ----> 3 clf1.fit(X_train1, y_train1)
#
# C:\Users\lgpc\Anaconda\lib\site-packages\IPython\core\displayhook.pyc in __call__(self, result)
#     241         """
#     242         self.check_for_underscore()
# --> 243         if result is not None and not self.quiet():
#     244             self.start_displayhook()
#     245             self.write_output_prompt()
#
# C:\Users\lgpc\Anaconda\lib\site-packages\IPython\core\displayhook.pyc in quiet(self)
#      92
#      93         sio = _io.StringIO(cell)
# ---> 94         tokens = list(tokenize.generate_tokens(sio.readline))
#      95
# ...

# %%
print "MSE - Training set : ",mean_squared_error(clf1.predict(X_train1), y_train1)
print "MSE - Test set : ",mean_squared_error(clf1.predict(X_test1), y_test1)

# %%
X2 = total1.drop('stars_x',axis=1)
X2 = X2.drop('user_id',axis=1)
X2 = X2.drop('business_id',axis=1)
X2 = X2.drop('review_id',axis=1)
y2 = total1['stars_x']

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, train_size=0.70, random_state=10000)
clf2 = KNeighborsClassifier(n_neighbors=5)
clf2.fit(X_train2, y_train2)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
print "MSE - Training set : ",mean_squared_error(clf2.predict(X_train2), y_train2)
print "MSE - Test set : ",mean_squared_error(clf2.predict(X_test2), y_test2)
# Out:
# MSE - Training set :  1.55588298434
# MSE - Test set :  2.23534986167

# %%
scores2 = cross_val_score(clf2, X2, y2)
print "Accuracy: %0.2f" % (scores2.mean())
# Out:
# Accuracy: 0.44

# %%
X2.head()
# Out:
#    useful  review_count_x  average_stars  review_count_y  stars_y
# 0      -1              53           4.82              10      3.0
# 1      -1              53           4.82               3      4.0
# 2      -1              53           4.82               5      4.0
# 3      -1              53           4.82              16      4.0
# 4      -1              53           4.82              55      4.5

# %%
from sklearn.metrics import mean_squared_error

# %%
#print clf.score(X_test, y_test)
print "MSE - Training set : ",mean_squared_error(clf.predict(X_train), y_train)
print "MSE - Test set : ",mean_squared_error(clf.predict(X_test), y_test)
# Out:
# MSE - Training set :  2.68457074517
# MSE - Test set :  4.28291612823

# %%
from sklearn.cross_validation import cross_val_score

# %%
scores = cross_val_score(clf, X, y)

# %%
print "Accuracy: %0.2f" % (scores.mean())
# Out:
# Accuracy: 0.29

# %%
print clf.predict(X_train)
# Out:
# [1 5 5 ..., 3 5 4]

# %%
result = pd.DataFrame(X_train['user_id'])

# %%
solve = pd.DataFrame(X_train['business_id'])

# %%
star = pd.DataFrame(clf.predict(X_train))

# %%
result = pd.concat([result, solve], axis=1)

# %%
result = result[['user_id', 'business_id']]

# %%
result.head()
# Out:
#          user_id  business_id
# 2822240  1523179        72338
# 1417607  2805925       140270
# 936819   4656647        47663
# 901255    443989        89649
# 2614912  1398383       140558

# %%
solve.head()
# Out:
#          business_id
# 2822240        72338
# 1417607       140270
# 936819         47663
# 901255         89649
# 2614912       140558

# %%
result1 = result

# %%
result1 = pd.concat([result1, star], axis=1)

# %%
result1.dropna()
# Out:
#            user_id  business_id    0
# 0        4194305.0       4899.0  5.0
# 2        4194305.0     134952.0  4.0
# 6        4194305.0      27721.0  5.0
# 7        4194305.0       4495.0  5.0
# 8        4194305.0      34629.0  4.0
# 9        4194305.0      16658.0  4.0
# 10       4194305.0      57923.0  5.0
# 14       4194305.0     136220.0  4.0
# 15       4194305.0      49269.0  5.0
# 16       4194305.0     100053.0  5.0
# 20       4194305.0      90790.0  5.0
# 23       4194305.0      57908.0  5.0
# 24       4194305.0      41100.0  5.0
# 25       4194305.0     114024.0  5.0
# 28       4194305.0      57708.0  5.0
# 30       4194305.0      50131.0  3.0
# 31       4194305.0     103939.0  5.0
# 35       4194305.0      83735.0  1.0
# 39       4194305.0      16120.0  2.0
# 40       4194305.0     125063.0  4.0
# 41       4194305.0     135404.0  4.0
# 42       4194305.0     103663.0  5.0
# 43       4194305.0      12318.0  5.0
# 44       4194305.0     125846.0  1.0
# ...

# %%
result1 = result1.reset_index(drop=True)

# %%
result1
# Out:
#            user_id  business_id    0
# 0        4194305.0       4899.0  5.0
# 1        4194305.0     134952.0  4.0
# 2        4194305.0      27721.0  5.0
# 3        4194305.0       4495.0  5.0
# 4        4194305.0      34629.0  4.0
# 5        4194305.0      16658.0  4.0
# 6        4194305.0      57923.0  5.0
# 7        4194305.0     136220.0  4.0
# 8        4194305.0      49269.0  5.0
# 9        4194305.0     100053.0  5.0
# 10       4194305.0      90790.0  5.0
# 11       4194305.0      57908.0  5.0
# 12       4194305.0      41100.0  5.0
# 13       4194305.0     114024.0  5.0
# 14       4194305.0      57708.0  5.0
# 15       4194305.0      50131.0  3.0
# 16       4194305.0     103939.0  5.0
# 17       4194305.0      83735.0  1.0
# 18       4194305.0      16120.0  2.0
# 19       4194305.0     125063.0  4.0
# 20       4194305.0     135404.0  4.0
# 21       4194305.0     103663.0  5.0
# 22       4194305.0      12318.0  5.0
# 23       4194305.0     125846.0  1.0
# ...

# %%
x=[]
for p in range(0,len(result1)) :
    c = int(result1['user_id'].ix[p])
    c = "%d" %(c)
    z1 = str(c)
    c = int(result1['business_id'].ix[p])
    c = "%d" %(c)
    z2 = str(c)
    y = z1+'-'+z2
    x.append(y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-5c5ede10a165> in <module>()
#       7     c = "%d" %(c)
#       8     z2 = str(c)
# ----> 9     y = z1+'-'+z2
#      10     x.append(y)
#
# KeyboardInterrupt:

# %%
result_final = pd.DataFrame(x)

# %%
result1.columns=['user_id','business_id','stars']

# %%
result_final1 = result1['stars']

# %%
result_final1.head()

# %%
result_final = pd.concat([result_final, result_final1], axis=1)

# %%
result_final.head()

# %%
result_final.columns=['user_id-business_id','stars']

# %%
result_final.head()

# %%
result_final.head()

# %%
result_final.to_csv('jiyun.csv', sep=',', index=False)

# %%
result_final2 = result1.drop_duplicates(['business_id'],keep='first')

# %%
result_final2 = result_final2.reset_index(drop=True)

# %%
x1=[]

for p in range(0,len(result_final2)) :
    c = int(result_final2['user_id'].ix[p])
    c = "%d" %(c)
    z1 = str(c)
    c = int(result_final2['business_id'].ix[p])
    c = "%d" %(c)
    z2 = str(c)
    y = z1+'-'+z2
    x1.append(y)

# %%
abc =  result_final2['stars']

# %%
result_final2 = pd.DataFrame(x1)

# %%
result_final2 = pd.concat([result_final2, abc], axis=1)

# %%
result_final2.head()

# %%
result_final2.columns=['user_id-business_id','stars']

# %%
result_final2.head()

# %%
result_final2.to_csv('jiyun2.csv', sep=',', index=False)

# %%
sample_original = pd.read_csv('sample.csv')

# %%
sample_original.drop('stars',axis=1)
# Out:
#        user_id-business_id
# 0           1781668-125363
# 1              139603-8758
# 2           1663836-126357
# 3            3269119-91569
# 4           2773720-106945
# 5             6498072-2943
# 6            7168503-94430
# 7           5369099-102911
# 8            2281428-78533
# 9            5269710-15308
# 10           1773927-81146
# 11          3769224-143306
# 12            852872-63185
# 13           956453-125754
# 14            312899-47527
# 15           6032095-30322
# 16          1076030-127749
# 17           5399025-72827
# 18          5692692-135521
# 19          3336574-119143
# 20           3809943-67446
# 21           4629909-24010
# 22           3079870-17532
# 23             1122619-218
# 24           4205773-80051
# 25           6768929-98805
# 26          3935304-122221
# 27           4901387-52447
# 28           2188414-26936
# 29          2983051-106039
# ...                    ...
# 182515      3202251-123413
# 182516        984701-92793
# ...

# %%
bus = []
use = []
for i in range (0, len(sample_original)) :
    save = str(sample_original.ix[i]).split(' ')[4]
    save = save[0:-6]
    #print save
    bus.append(save.split('-')[1])
    use.append(save.split('-')[0])
    #print use[i],' ',bus[i]

# %%
solution = pd.DataFrame(use)

# %%
solution.head()
# Out:
#          0
# 0  1781668
# 1   139603
# 2  1663836
# 3  3269119
# 4  2773720

# %%
solution['business']=bus

# %%
solution.head()
# Out:
#          0 business
# 0  1781668   125363
# 1   139603     8758
# 2  1663836   126357
# 3  3269119    91569
# 4  2773720   106945

# %%
solution.columns=['user_id','business_id']

# %%
solution.head()
# Out:
#    user_id business_id
# 0  1781668      125363
# 1   139603        8758
# 2  1663836      126357
# 3  3269119       91569
# 4  2773720      106945

# %%
solution.to_csv('solution.csv', sep=',', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-680acaefad42> in <module>()
# ----> 1 solution.to_csv('solution.csv', sep=',', index=False)
#
# NameError: name 'solution' is not defined

# %%
solution = pd.read_csv('solution.csv')

# %%
user1 = pd.read_csv('user.csv')

# %%
user1 = user1.drop('compliment_photos',axis=1)
user1 = user1.drop('compliment_list',axis=1)
user1 = user1.drop('compliment_funny',axis=1)
user1 = user1.drop('compliment_plain', axis=1)
user1 = user1.drop('fans',axis=1)
user1 = user1.drop('compliment_note',axis=1)
user1 = user1.drop('compliment_writer',axis=1)
user1 = user1.drop('compliment_cute',axis=1)
user1 = user1.drop('funny',axis=1)
user1 = user1.drop('compliment_more',axis=1)
user1 = user1.drop('compliment_hot',axis=1)
user1 = user1.drop('compliment_profile',axis=1)
user1 = user1.drop('compliment_cool',axis=1)
user1 = user1.drop('cool',axis=1)

# %%
user1.head()
# Out:
#   yelping_since  useful  review_count     elite  type  average_stars  user_id  \
# 0    2008-10-30      -1            53  ['None']  user           4.82  4194305
# 1    2015-05-31       0             2  ['None']  user           5.00        5
# 2    2010-07-07      88           159  ['None']  user           3.58        6
# 3    2014-09-02       0             5  ['None']  user           1.13  6291463
# 4    2014-11-12       1            28  ['None']  user           4.03  6291465
#
#                                              friends    name
# 0                                         ['908184']      ay
# 1                                         ['908184']  Chelle
# 2  ['1627413', '1077703', '2799502', '5687445', '...   Kathy
# 3                                         ['908184']    Alan
# 4  ['667825', '2790525', '6743614', '5645148', '2...    Joee

# %%
user1 = user1.drop('yelping_since',axis=1)
user1 = user1.drop('elite',axis=1)
user1 = user1.drop('type',axis=1)
user1 = user1.drop('friends',axis=1)
user1 = user1.drop('name',axis=1)

# %%
user1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029432 entries, 0 to 1029431
# Data columns (total 4 columns):
# useful           1029432 non-null int64
# review_count     1029432 non-null int64
# average_stars    1029432 non-null float64
# user_id          1029432 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 31.4 MB

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029432 entries, 0 to 1029431
# Data columns (total 4 columns):
# useful           1029432 non-null int64
# review_count     1029432 non-null int64
# average_stars    1029432 non-null float64
# user_id          1029432 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 31.4 MB

# %%
user1.columns=['useful','review_count','average_stars','user_id']
solution.columns=['user_id','business_id']

# %%
solution1 =  pd.concat([user1, solution], axis=1, join='inner')

# %%
solution2 = pd.concat([solution1, business], axis=1, join='inner')

# %%
solution1.head()
# Out:
#    useful  review_count  average_stars  user_id  user_id  business_id
# 0      -1            53           4.82  4194305  1781668       125363
# 1       0             2           5.00        5   139603         8758
# 2      88           159           3.58        6  1663836       126357
# 3       0             5           1.13  6291463  3269119        91569
# 4       1            28           4.03  6291465  2773720       106945

# %%
solution2.head()
# Out:
#    useful  review_count  average_stars  user_id  user_id  business_id  \
# 0      -1            53           4.82  4194305  1781668       125363
# 1       0             2           5.00        5   139603         8758
# 2      88           159           3.58        6  1663836       126357
# 3       0             5           1.13  6291463  3269119        91569
# 4       1            28           4.03  6291465  2773720       106945
#
#    business_id  review_count  stars
# 0            0            12    4.0
# 1            1             4    3.0
# 2            2            79    3.5
# 3            3           105    3.0
# 4            4             4    3.0

# %%
solution = solution.convert_objects(convert_numeric=True)
# Out:
# C:\Users\lgpc\Anaconda\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
solution1 = solution1.convert_objects(convert_numeric=True)
# Out:
# C:\Users\lgpc\Anaconda\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
solution2 = solution2.convert_objects(convert_numeric=True)
# Out:
# C:\Users\lgpc\Anaconda\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
type(solution['user_id'][1])
# Out:
# numpy.int64

# %%
type(user1['user_id'][1])
# Out:
# numpy.int64

# %%
solution1.head()
# Out:
#    useful  review_count  average_stars  user_id  user_id  business_id
# 0      -1            53           4.82  4194305  1781668       125363
# 1       0             2           5.00        5   139603         8758
# 2      88           159           3.58        6  1663836       126357
# 3       0             5           1.13  6291463  3269119        91569
# 4       1            28           4.03  6291465  2773720       106945

# %%
solution1 = pd.merge(user1,solution,how='right',on=['user_id'])

# %%
solution1 = pd.merge(business,solution1,how='right',on=['business_id'])

# %%
solution1.head()
# Out:
#    business_id  review_count_x  stars  useful  review_count_y  average_stars  \
# 0            2              79    3.5     107             125           3.53
# 1            2              79    3.5       4              37           2.64
# 2            2              79    3.5       0              27           4.00
# 3            2              79    3.5      72              76           3.72
# 4            2              79    3.5      -3              34           4.34
#
#    user_id
# 0  5290317
# 1   532698
# 2  7042964
# 3  5084619
# 4  3007795

# %%
solution1 = solution1[['useful','review_count_x','average_stars','user_id','business_id','review_count_y','stars']]

# %%
solution1.head()
# Out:
#    useful  review_count_x  average_stars  user_id  business_id  \
# 0     107              79           3.53  5290317            2
# 1       4              79           2.64   532698            2
# 2       0              79           4.00  7042964            2
# 3      72              79           3.72  5084619            2
# 4      -3              79           4.34  3007795            2
#
#    review_count_y  stars
# 0             125    3.5
# 1              37    3.5
# 2              27    3.5
# 3              76    3.5
# 4              34    3.5

# %%
solution2 = solution2[['useful','review_count_x','average_stars','review_count_y','stars']]

# %%
solution2 = pd.merge(business,solution1,how='right',on=['business_id'])

# %%
solution2.head()
# Out:
#    useful  review_count_x  average_stars  review_count_y  stars
# 0     107              79           3.53             125    3.5
# 1       4              79           2.64              37    3.5
# 2       0              79           4.00              27    3.5
# 3      72              79           3.72              76    3.5
# 4      -3              79           4.34              34    3.5

# %%
solution_star2 = pd.DataFrame(clf2.predict(solution2))

# %%
solution_real2 = solution1[['user_id','business_id']]

# %%
solution_real2['stars'] = solution_star2
# Out:
# C:\Users\lgpc\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
x2=[]
for p in range(0,len(solution_real2)) :
    c = solution_real2['user_id'].ix[p]
    z1 = str(c)
    c = solution_real2['business_id'].ix[p]
    z2 = str(c)
    y = z1+'-'+z2
    x2.append(y)

# %%
solution_csv2 = pd.DataFrame(x2)
solution_csv2['stars'] = solution_star2
solution_csv2.columns=['user_id-business_id','stars']
solution_csv2.to_csv('submit3_final.csv', sep=',', index=False)

# %%
solution1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182545 entries, 0 to 182544
# Data columns (total 5 columns):
# useful           182545 non-null int64
# review_count     182545 non-null int64
# average_stars    182545 non-null float64
# user_id          182545 non-null int64
# business_id      182545 non-null int64
# dtypes: float64(1), int64(4)
# memory usage: 8.4 MB

# %%
solution_star.head()
# Out:
#    0
# 0  5
# 1  5
# 2  4
# 3  5
# 4  5

# %%
solution_real = solution1[['user_id','business_id']]

# %%
solution_real['stars'] = solution_star
# Out:
# C:\Users\lgpc\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
solution_real.head()
# Out:
#    user_id  business_id  stars
# 0  4194305        11798      5
# 1  4194305       116083      5
# 2       11         3056      2
# 3       66        21667      5
# 4      114        80493      4

# %%
x=[]
for p in range(0,len(solution_real)) :
    c = solution_real['user_id'].ix[p]
    z1 = str(c)
    c = solution_real['business_id'].ix[p]
    z2 = str(c)
    y = z1+'-'+z2
    x.append(y)

# %%
solution_csv = pd.DataFrame(x)

# %%
solution_csv['stars'] = solution_star

# %%
solution_csv.columns=['user_id-business_id','stars']

# %%
solution_csv.head()
# Out:
#   user_id-business_id  stars
# 0       4194305-11798      5
# 1      4194305-116083      5
# 2             11-3056      2
# 3            66-21667      5
# 4           114-80493      4

# %%
solution_csv.to_csv('submit1.csv', sep=',', index=False)

# %%
solution_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182545 entries, 0 to 182544
# Data columns (total 2 columns):
# user_id-business_id    182545 non-null object
# stars                  182545 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.8+ MB
